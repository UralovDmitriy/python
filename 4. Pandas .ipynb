# %% [markdown]
# ### Learn Pandas in 10 minutes
#
# [https://pandas.pydata.org/pandas-docs/stable/10min.html](https://pandas.pydata.org/pandas-docs/stable/10min.html)

# %% [markdown]
# ### Import pandas, numpy and matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import the dataset from this [address]('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
df = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Show the first 10 entries

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### What is the number of observations in the dataset?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
df = pd.read_csv(url, sep = '\t')

len(df)
# Out:
# 4622

# %% [markdown]
# ### What is the number of columns in the dataset?

# %%
len(df.columns)
# Out:
# 5

# %% [markdown]
# ### Which was the most-ordered item and how many times it was ordered?

# %%
print(df["item_name"].value_counts().idxmax())
print(df["item_name"].value_counts().max())
# Out:
# Chicken Bowl
# 726

# %% [markdown]
# ### How many different items are sold?

# %%
df.groupby("item_name").sum()["quantity"].sort_values(ascending = False)
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %% [markdown]
# ### How many items were orderd in total?

# %%
len(df.groupby("item_name"))
# Out:
# 50

# %% [markdown]
# ### Turn the item price into a float

# %%
df["item_clearprice"] = df["item_price"].apply(lambda x: float(x[1:]))
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### What is the price of each item?

# %%
df[["item_name", "item_price"]].drop_duplicates().reset_index()
# Out:
#      index                              item_name item_price
# 0        0           Chips and Fresh Tomato Salsa     $2.39
# 1        1                                   Izze     $3.39
# 2        2                       Nantucket Nectar     $3.39
# 3        3  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4        4                           Chicken Bowl    $16.98
# 5        5                           Chicken Bowl    $10.98
# 6        6                          Side of Chips     $1.69
# 7        7                          Steak Burrito    $11.75
# 8        8                       Steak Soft Tacos     $9.25
# 9        9                          Steak Burrito     $9.25
# 10      10                    Chips and Guacamole     $4.45
# 11      11                   Chicken Crispy Tacos     $8.75
# 12      12                     Chicken Soft Tacos     $8.75
# 13      13                           Chicken Bowl    $11.25
# 14      16                        Chicken Burrito     $8.49
# ...

# %% [markdown]
# ### How much was the revenue for the period in the dataset?

# %%
(df["item_clearprice"] * df["quantity"]).sum()
# Out:
# 39237.02

# %% [markdown]
# ### How many orders were made in the period?

# %%
df["order_id"].value_counts().count()
# Out:
# 1834

# %% [markdown]
# ### What is the average revenue amount per order?

# %%
(df["item_clearprice"] * df["quantity"]).sum() / df["quantity"].sum()
# Out:
# 7.8915969428801285

# %% [markdown]
# ### Merge the table ```dfa``` that contains order date and order id with ```df``` and plot daily revenue

# %%
dfa = pd.DataFrame({"date": np.random.choice(pd.date_range(start="20170101", end="20170201"), size=df.order_id.value_counts().index.size),
                   "order_id": np.arange(df.order_id.value_counts().index.size)})
dat = dfa["date"][df["order_id"] - 1]
dat.index = np.arange(dat.size)
df["date"] = dat
ans = df.groupby("date")["item_clearprice"].sum()
plt.plot(ans.index, ans.values)
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ### Create a histogram of the top 5 items bought

# %%
plt.hist(df.item_name.value_counts()[:5], bins = 10)
plt.show()

# %% [markdown]
# ### Sort the dataset by the name of the item

# %%
df.sort_values(by = ['item_name'])
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# 3422      1373         1  6 Pack Soft Drink
# 553        230         1  6 Pack Soft Drink
# 1916       774         1  6 Pack Soft Drink
# 1922       776         1  6 Pack Soft Drink
# 1937       784         1  6 Pack Soft Drink
# 3836      1537         1  6 Pack Soft Drink
# 298        129         1  6 Pack Soft Drink
# 1976       798         1  6 Pack Soft Drink
# 1167       481         1  6 Pack Soft Drink
# 3875      1554         1  6 Pack Soft Drink
# 1124       465         1  6 Pack Soft Drink
# 3886      1558         1  6 Pack Soft Drink
# 2108       849         1  6 Pack Soft Drink
# 3010      1196         1  6 Pack Soft Drink
# 4535      1803         1  6 Pack Soft Drink
# ...

# %% [markdown]
# ### How many times were a Veggie Salad Bowl ordered?

# %%
df.loc[df["item_name"] == "Veggie Salad Bowl"].sum()["quantity"]
# Out:
# 18

# %% [markdown]
# ### How many times people orderd more than one Canned Soda?

# %%
df.loc[(df["item_name"] == "Canned Soda") & (df["quantity"] > 1)].size
# Out:
# 120

# %% [markdown]
# ### Create a scatterplot with the number of items orderered per order price

# %%
p = df.groupby("order_id")["item_clearprice"].sum()
q = df.groupby("order_id")["quantity"].sum()
plt.scatter(p.values, q.values)
plt.xlabel("Price")
plt.ylabel("Number of items")
plt.show()

# %% [markdown]
# Submit solution to [https://goo.gl/forms/0iOA8xFJ2o5qONBr2](https://goo.gl/forms/0iOA8xFJ2o5qONBr2)
